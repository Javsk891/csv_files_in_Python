# %%
import numpy as np
import pandas as pd
# Load the data into the DataFrame 
# Data of endangered Language 
data = pd.read_csv('C:\\Users\\USUARIO\\Desktop\\JAVO\\Python for Data Analisis\\scriptsLecture\\scriptsLecture\\section5\\endangeredLang.csv')
data.head(10)
# Out:
#      ID              Name in English  \
# 0  1022                South Italian
# 1  1023                     Sicilian
# 2   383                    Low Saxon
# 3   335                   Belarusian
# 4   382                      Lombard
# 5   405                       Romani
# 6  2211             Yiddish (Israel)
# 7  1586                        Gondi
# 8  1020         Limburgian-Ripuarian
# 9  1943  Quechua of Southern Bolivia
#
#                                            Countries  \
# 0                                              Italy
# 1                                              Italy
# 2  Germany, Denmark, Netherlands, Poland, Russian...
# 3  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                 Italy, Switzerland
# 5  Albania, Germany, Austria, Belarus, Bosnia and...
# 6                                             Israel
# 7                                              India
# 8                      Germany, Belgium, Netherlands
# ...

# %%
# Isolate a column
data['Countries']
# Out:
# 0                                                   Italy
# 1                                                   Italy
# 2       Germany, Denmark, Netherlands, Poland, Russian...
# 3       Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                      Italy, Switzerland
#                               ...
# 2717                                                Japan
# 2718                                             Colombia
# 2719                                             Colombia
# 2720                                      India, Pakistan
# 2721                                                 Oman
# Name: Countries, Length: 2722, dtype: object

# %%
# Isolate two columns
data[['Countries','Degree of endangerment']]
# Out:
#                                               Countries Degree of endangerment
# 0                                                 Italy             Vulnerable
# 1                                                 Italy             Vulnerable
# 2     Germany, Denmark, Netherlands, Poland, Russian...             Vulnerable
# 3     Belarus, Latvia, Lithuania, Poland, Russian Fe...             Vulnerable
# 4                                    Italy, Switzerland  Definitely endangered
# ...                                                 ...                    ...
# 2717                                              Japan    Severely endangered
# 2718                                           Colombia  Definitely endangered
# 2719                                           Colombia  Definitely endangered
# 2720                                    India, Pakistan  Definitely endangered
# 2721                                               Oman  Critically endangered
#
# [2722 rows x 2 columns]

# %%
# Isolate rows
data[3:15]
# Out:
#       ID              Name in English  \
# 3    335                   Belarusian
# 4    382                      Lombard
# 5    405                       Romani
# 6   2211             Yiddish (Israel)
# 7   1586                        Gondi
# 8   1020         Limburgian-Ripuarian
# 9   1943  Quechua of Southern Bolivia
# 10  1565                      Kumaoni
# 11   755                       Aymara
# 12   349             Emilian-Romagnol
# 13   399                  Piedmontese
# 14  1021                      Venetan
#
#                                             Countries  \
# 3   Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                  Italy, Switzerland
# 5   Albania, Germany, Austria, Belarus, Bosnia and...
# 6                                              Israel
# 7                                               India
# 8                       Germany, Belgium, Netherlands
# 9                    Bolivia (Plurinational State of)
# ...

# %%
# Condirional selction 
data[data['Number of speakers']<5000] # Isolate the number of speakers
# Out:
#         ID    Name in English           Countries Country codes alpha 3  \
# 740   1125              Jirel               Nepal                   NPL
# 741    468             Dolgan  Russian Federation                   RUS
# 742   2057  Romani (Colombia)            Colombia                   COL
# 743   1160               Tsum               Nepal                   NPL
# 744    993  Northern Tlapanec              Mexico                   MEX
# ...    ...                ...                 ...                   ...
# 2534   131             |'Auni        South Africa                   ZAF
# 2535   136               |Xam        South Africa                   ZAF
# 2536  1443            ǁKu ǁ'e        South Africa                   ZAF
# 2537  1445             ǁKx'au        South Africa                   ZAF
# 2538   130             ǁXegwi        South Africa                   ZAF
#
#      Degree of endangerment  Number of speakers  Latitude  Longitude  \
# ...

# %%
# Remove the first two rows
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.DataFrame(data)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Remove the first row, row at index zero
df.drop(df.index[:5], inplace=True)
df
# Out:
#         ID              Name in English  \
# 8     1020         Limburgian-Ripuarian
# 9     1943  Quechua of Southern Bolivia
# 10    1565                      Kumaoni
# 11     755                       Aymara
# 12     349             Emilian-Romagnol
# ...    ...                          ...
# 2717  1972                     Yonaguni
# 2718  2018                       Yucuna
# 2719  2015            Yurutí (Colombia)
# 2720  2716                    Zangskari
# 2721  2177                      Zidgali
#
#                                           Countries Country codes alpha 3  \
# 8                     Germany, Belgium, Netherlands         DEU, BEL, NLD
# 9                  Bolivia (Plurinational State of)                   BOL
# 10                                     India, Nepal              IND, NPL
# 11    Bolivia (Plurinational State of), Chile, Peru         BOL, CHL, PER
# 12                                Italy, San Marino              ITA, SMR
# ...

# %%
# Remove the fisrt two rows, at index zero
df.drop(df.index[:6], inplace=True)
df
# Out:
#         ID    Name in English                 Countries Country codes alpha 3  \
# 14    1021            Venetan  Croatia, Italy, Slovenia         HRV, ITA, SVN
# 15    1985             Zazaki                    Turkey                   TUR
# 16    1591      Kurux (India)                     India                   IND
# 17    2065            Tamajeq                     Niger                   NER
# 18    1585               Tulu                     India                   IND
# ...    ...                ...                       ...                   ...
# 2717  1972           Yonaguni                     Japan                   JPN
# 2718  2018             Yucuna                  Colombia                   COL
# 2719  2015  Yurutí (Colombia)                  Colombia                   COL
# 2720  2716          Zangskari           India, Pakistan              IND, PAK
# 2721  2177            Zidgali                      Oman                   OMN
#
# ...

# %%
# Drop a column called Latitud
df.drop(['Latitude'], axis=1, inplace = True)
df
# Out:
#         ID    Name in English                 Countries Country codes alpha 3  \
# 14    1021            Venetan  Croatia, Italy, Slovenia         HRV, ITA, SVN
# 15    1985             Zazaki                    Turkey                   TUR
# 16    1591      Kurux (India)                     India                   IND
# 17    2065            Tamajeq                     Niger                   NER
# 18    1585               Tulu                     India                   IND
# ...    ...                ...                       ...                   ...
# 2717  1972           Yonaguni                     Japan                   JPN
# 2718  2018             Yucuna                  Colombia                   COL
# 2719  2015  Yurutí (Colombia)                  Colombia                   COL
# 2720  2716          Zangskari           India, Pakistan              IND, PAK
# 2721  2177            Zidgali                      Oman                   OMN
#
# ...

# %%
# Subsetting and indexing 
data[10:]
# Out:
#         ID    Name in English                                      Countries  \
# 10    1565            Kumaoni                                   India, Nepal
# 11     755             Aymara  Bolivia (Plurinational State of), Chile, Peru
# 12     349   Emilian-Romagnol                              Italy, San Marino
# 13     399        Piedmontese                                          Italy
# 14    1021            Venetan                       Croatia, Italy, Slovenia
# ...    ...                ...                                            ...
# 2717  1972           Yonaguni                                          Japan
# 2718  2018             Yucuna                                       Colombia
# 2719  2015  Yurutí (Colombia)                                       Colombia
# 2720  2716          Zangskari                                India, Pakistan
# 2721  2177            Zidgali                                           Oman
#
# ...

# %%
# Select all columns for rows of index values 0 and 10
data.loc[[0,10], :]
# Out:
#       ID Name in English     Countries Country codes alpha 3  \
# 0   1022   South Italian         Italy                   ITA
# 10  1565         Kumaoni  India, Nepal              IND, NPL
#
#    Degree of endangerment  Number of speakers  Latitude  Longitude  \
# 0              Vulnerable           7500000.0   40.9798    15.2490
# 10             Vulnerable           2003783.0   29.4778    79.8486
#
#                           Description of the location
# 0   Campania, Lucania (Basilicata), Abruzzi (Abruz...
# 10  Uttarakhand, also in Uttar Pradesh, Madhya Pra...

# %%
# Isolate Rows and Columns
data[['Countries', 'Name in English']][4:8]
# Out:
#                                            Countries   Name in English
# 4                                 Italy, Switzerland           Lombard
# 5  Albania, Germany, Austria, Belarus, Bosnia and...            Romani
# 6                                             Israel  Yiddish (Israel)
# 7                                              India             Gondi

# %%
# Subset data on the basis of row labels 
data.head(4)
# Out:
#      ID Name in English                                          Countries  \
# 0  1022   South Italian                                              Italy
# 1  1023        Sicilian                                              Italy
# 2   383       Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335      Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
#
#           Country codes alpha 3 Degree of endangerment  Number of speakers  \
# 0                           ITA             Vulnerable           7500000.0
# 1                           ITA             Vulnerable           5000000.0
# 2       DEU, DNK, NLD, POL, RUS             Vulnerable           4800000.0
# 3  BRB, LVA, LTU, POL, RUS, UKR             Vulnerable           4000000.0
#
#    Latitude  Longitude                        Description of the location
# 0   40.9798    15.2490  Campania, Lucania (Basilicata), Abruzzi (Abruz...
# ...

# %%
# Select all columns for rows of index values 0 and 10
data.loc[[0,10], :]
# Out:
#       ID Name in English     Countries Country codes alpha 3  \
# 0   1022   South Italian         Italy                   ITA
# 10  1565         Kumaoni  India, Nepal              IND, NPL
#
#    Degree of endangerment  Number of speakers  Latitude  Longitude  \
# 0              Vulnerable           7500000.0   40.9798    15.2490
# 10             Vulnerable           2003783.0   29.4778    79.8486
#
#                           Description of the location
# 0   Campania, Lucania (Basilicata), Abruzzi (Abruz...
# 10  Uttarakhand, also in Uttar Pradesh, Madhya Pra...

# %%
data.head(5)
# Out:
#      ID Name in English                                          Countries  \
# 0  1022   South Italian                                              Italy
# 1  1023        Sicilian                                              Italy
# 2   383       Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335      Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4   382         Lombard                                 Italy, Switzerland
#
#           Country codes alpha 3 Degree of endangerment  Number of speakers  \
# 0                           ITA             Vulnerable           7500000.0
# 1                           ITA             Vulnerable           5000000.0
# 2       DEU, DNK, NLD, POL, RUS             Vulnerable           4800000.0
# 3  BRB, LVA, LTU, POL, RUS, UKR             Vulnerable           4000000.0
# 4                      ITA, CHE  Definitely endangered           3500000.0
#
# ...

# %%
# Isolate by rows names 
data[data.Countries == 'Italy']
# Out:
#         ID    Name in English Countries Country codes alpha 3  \
# 0     1022      South Italian     Italy                   ITA
# 1     1023           Sicilian     Italy                   ITA
# 13     399        Piedmontese     Italy                   ITA
# 36     337        Campidanese     Italy                   ITA
# 53     353           Friulian     Italy                   ITA
# 80     381         Logudorese     Italy                   ITA
# 157    408          Sassarese     Italy                   ITA
# 170    356          Gallurese     Italy                   ITA
# 197   1347           Arbëresh     Italy                   ITA
# 212   1330     Gallo-Sicilian     Italy                   ITA
# 320    565              Ladin     Italy                   ITA
# 391   1614    Griko (Salento)     Italy                   ITA
# 510   1343  Algherese Catalan     Italy                   ITA
# 729   1349    Molise Croatian     Italy                   ITA
# ...

# %%
# Isolate by two row labels 
x = data.loc[data['Countries'].isin(['Italy','Germany'])]

# %%
x.head(4)
# Out:
#       ID Name in English Countries Country codes alpha 3  \
# 0   1022   South Italian     Italy                   ITA
# 1   1023        Sicilian     Italy                   ITA
# 13   399     Piedmontese     Italy                   ITA
# 36   337     Campidanese     Italy                   ITA
#
#    Degree of endangerment  Number of speakers  Latitude  Longitude  \
# 0              Vulnerable           7500000.0   40.9798    15.2490
# 1              Vulnerable           5000000.0   37.4399    14.5019
# 13  Definitely endangered           2000000.0   45.2013     7.8662
# 36  Definitely endangered            900000.0   39.2991     8.9868
#
#                           Description of the location
# 0   Campania, Lucania (Basilicata), Abruzzi (Abruz...
# 1   Sicily (Sicilia), southern and central Calabri...
# 13  Piedmont Region except the Novara Province, th...
# 36                                  southern Sardinia

# %%
# Sort in descending order 
small = data.sort_values(by = 'Number of speakers', ascending = True) 
small.head(4)
# Out:
#         ID         Name in English                         Countries  \
# 2538   130                  ǁXegwi                      South Africa
# 2374   477                   Kamas                Russian Federation
# 2373   696  Judeo-Berber (Morocco)                           Morocco
# 2372  1925                    Jorá  Bolivia (Plurinational State of)
#
#      Country codes alpha 3 Degree of endangerment  Number of speakers  \
# 2538                   ZAF                Extinct                 0.0
# 2374                   RUS                Extinct                 0.0
# 2373                   MAR                Extinct                 0.0
# 2372                   BOL  Critically endangered                 0.0
#
#       Latitude  Longitude                        Description of the location
# 2538  -25.3500    30.9900                 Lake Chrissie, Eastern Transvaal.
# 2374   57.9964    92.8784  formerly spoken in the eastern part of the Min...
# ...

# %%
# Bystatus.describe()
byStatus = data.groupby('Degree of endangerment')
byStatus.head(10)
# Out:
#         ID              Name in English  \
# 0     1022                South Italian
# 1     1023                     Sicilian
# 2      383                    Low Saxon
# 3      335                   Belarusian
# 4      382                      Lombard
# 5      405                       Romani
# 6     2211             Yiddish (Israel)
# 7     1586                        Gondi
# 8     1020         Limburgian-Ripuarian
# 9     1943  Quechua of Southern Bolivia
# 10    1565                      Kumaoni
# 11     755                       Aymara
# 12     349             Emilian-Romagnol
# 13     399                  Piedmontese
# 14    1021                      Venetan
# 19    1556                       Kangdi
# 30     377                     Ligurian
# 36     337                  Campidanese
# 38     989          Quechua of Ayacucho
# 39    1117                        Newar
# 48     398                       Picard
# 62     375                 Languedocian
# ...

# %%
data.groupby(['Degree of endangerment']).count()
# Out:
#                          ID  Name in English  Countries  \
# Degree of endangerment
# Critically endangered   607              607        607
# Definitely endangered   680              680        679
# Extinct                 253              253        253
# Severely endangered     554              554        554
# Vulnerable              628              628        628
#
#                         Country codes alpha 3  Number of speakers  Latitude  \
# Degree of endangerment
# Critically endangered                     607                 544       606
# Definitely endangered                     679                 635       680
# Extinct                                   253                 244       252
# Severely endangered                       554                 505       554
# Vulnerable                                628                 611       627
#
#                         Longitude  Description of the location
# Degree of endangerment
# ...

# %%
# Out:
#      ID                 EnglishNames  \
# 0  1022                South Italian
# 1  1023                     Sicilian
# 2   383                    Low Saxon
# 3   335                   Belarusian
# 4   382                      Lombard
# 5   405                       Romani
# 6  2211             Yiddish (Israel)
# 7  1586                        Gondi
# 8  1020         Limburgian-Ripuarian
# 9  1943  Quechua of Southern Bolivia
#
#                                            Countries  \
# 0                                              Italy
# 1                                              Italy
# 2  Germany, Denmark, Netherlands, Poland, Russian...
# 3  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                 Italy, Switzerland
# 5  Albania, Germany, Austria, Belarus, Bosnia and...
# 6                                             Israel
# 7                                              India
# 8                      Germany, Belgium, Netherlands
# ...
